# %% [markdown]
# # Standard Maxx Analysis Template

# %% [markdown]
# ## Notes
# **Overview:**
# **Rationale:**
# **Date of Experiment:**
# **Genotypes:**
# **Sex:**
# **Light Paradigm:**
# **Design:**
# **Misc:**

# %% [markdown]
# ## Configuration
# Configuration was standard. No new or untested code.

# %%
#%autoreload 1
import warnings
from Arena import *
import Tracker
import TwoChoiceTracker
from ExperimentalDesign import *
from Parameters import *

# Suppress all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Parameters
# Just a standard arena max, accepting the default values and a Two-Choice Tracker.

# %%
p=Parameters()
p.set_colloseum_values(TrackingType.TWOCHOICETRACKER)
p.print()
# Out:
# tracking_type: TrackingType.TWOCHOICETRACKER
# fps: 0
# mm_per_pixel: 0.145
# speed_window_seconds: 1
# micromove_speed_mm_sec: [0.2, 2]
# walking_speed_mm_sec: 2
# sleep_threshold_min: 5
# interaction_distances: [8]

# %% [markdown]
# ## Read in the data
#
# Next we will read in the data to an Arena object. The format is`Arena(ExperimentName, parameters, data_path="./")`. This will automatically calculate all relevant metrics for the tracking type in question.
#
# The name of the experiment and predefined parameters object are required, but _data_path_ is optional (if no data directory is specified, it defaults to the current working directory).
#
# The following files must be present in the defined data directory :
# * The DTrack experiment file, which is an excel sheet with the name '_ExperimentName.xlsx_'.
# * The DTrack data files themselves, which are named '_ExperimentName_Data_1.csv_', '_ExperimentName_Data_2.csv_', etc.
# * An experiment file (most of the time, definitely for a TwoChoiceTracker), which is named '_ExperimentName_Design.txt_'. Note that you can incorporate flipped axes to orient lights for data visualization.

# %%
arena = Arena.Arena(p,data_path='./Data/')
arena.print_short_data_quality_report()
# Out:
#    Tracker  HighQuality  NotFound  Indiscernible  StartMinutes  EndMinutes
# 0    T_0_0          1.0       0.0            0.0      0.000517   80.021446
# 1    T_1_0          1.0       0.0            0.0      0.000517   80.021446
# 2    T_2_0          1.0       0.0            0.0      0.000517   80.021446
# 3    T_3_0          1.0       0.0            0.0      0.000517   80.021446
# 4    T_4_0          1.0       0.0            0.0      0.000517   80.021446
# 5    T_5_0          1.0       0.0            0.0      0.000517   80.021446
# 6    T_6_0          1.0       0.0            0.0      0.000517   80.021446
# 7    T_7_0          1.0       0.0            0.0      0.000517   80.021446
# 8    T_8_0          1.0       0.0            0.0      0.000517   80.021446
# 9    T_9_0          1.0       0.0            0.0      0.000517   80.021446
# 10  T_10_0          1.0       0.0            0.0      0.000517   80.021446
# 11  T_11_0          1.0       0.0            0.0      0.000517   80.021446
# 12  T_12_0          1.0       0.0            0.0      0.000517   80.021446
# 13  T_13_0          1.0       0.0            0.0      0.000517   80.021446
# 14  T_14_0          1.0       0.0            0.0      0.000517   80.021446
# 15  T_15_0          1.0       0.0            0.0      0.000517   80.021446
# 16  T_16_0          1.0       0.0            0.0      0.000517   80.021446
# 17  T_17_0          1.0       0.0            0.0      0.000517   80.021446
# ****************************************************
# All data quality is above 0.9.
# ****************************************************

# %% [markdown]
# ## Summary
# Get the summary results for all trackers, including treatments, etc.
# This will copy the results to the clipboard and save the data in a file called '_ExperimentName_Summary.csv_'.
# The semicolon at the end of the command will suppress the output to this notebook.  Remove it if you want to see the results dataframe.

# %%
arena.summarize(copy_to_clipboard=True,write_to_csvfile=True);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/PyTrackingAnalysis/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TotalDistance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 arena.summarize(copy_to_clipboard=True,write_to_csvfile=True)
#
# File ~/GitHubLocal/PyTrackingAnalysis/Arena.py:356, in Arena.summarize(self, range_minutes, copy_to_clipboard, write_to_csvfile, remove_partners)
#     354 summaries = []
#     355 for key, tracker in self.trackers.items():
# --> 356     summary = tracker.summarize(range_minutes)
#     357     summaries.append(summary)
#     359 # Concatenate all summaries into a single DataFrame
#
# File ~/GitHubLocal/PyTrackingAnalysis/TwoChoiceTracker.py:261, in TwoChoiceTracker.summarize(self, range_minutes)
#     260 def summarize(self, range_minutes=(0,0)):
# --> 261     tmp = Tracker.Tracker.summarize(self, range_minutes)
#     262     final_pi = self.get_final_pi(range_minutes)
#     263     final_perc = self.get_final_percentage(range_minutes)
#
# File ~/GitHubLocal/PyTrackingAnalysis/Tracker.py:220, in Tracker.summarize(self, range_minutes)
#     217 if(self.tracking_region_design is not None):
#     218     treatment = self.tracking_region_design['Treatment'].iat[0]
# --> 220 total_distance_dtrack = (data_subset['TotalDistance'].iat[0] - data_subset['TotalDistance'].iat[0])*self.parameters.mm_per_pixel
#     221 #tmp = (f"Treatment: {treatment}, Name: {self.name}, ObsMin: {obs_minutes:.2f}, Sleeping: {perc_sleeping:.2f}, Walking: {perc_walking:.2f}, Micro: {perc_micro:.2f}, Resting: {perc_resting:.2f}, AvgSpeed: {avg_speed:.2f}, TotalDist: {total_distance:.2f}, TotalDist2: {total_distance_dtrack:.2f}, StartMin: {start_minutes:.2f}, EndMin: {end_minutes:.2f}")
#     222 result = pd.Series([treatment, self.name,self.tracking_region_id,self.object_id,obs_minutes,total_distance,total_distance_min,perc_sleeping,perc_walking,perc_micro,perc_resting,avg_speed,perc_highquality,start_minutes,end_minutes])
#
# File ~/anaconda3/envs/PyTrackingAnalysis/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/PyTrackingAnalysis/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'TotalDistance'

# %% [markdown]
# Or you can also create a faceted summary if you want to separate the different phases of the experiment.
# The file name will be '_ExperimentName_Summary_Facet.csv_'.

# %%
arena.summarize_facet(cutoffs=(10,70),copy_to_clipboard=True,write_to_csvfile=True);

# %% [markdown]
# ## Plotting
# There are lots of cool plotting funtions.  Some are shown below.

# %% [markdown]
# **Facet plots:** First of PI, then Percentage, then Total Distance (in mm/min).
# Cutoffs separate the acclimaton phase from the experiment phase from the cool down phase.

# %%
arena.plot_pi_facet(cutoffs=(10,70))

# %%
arena.run_pairwise_comparisons_facet(metric="FinalPI",cutoffs=(10,70))

# %%
arena.plot_percentage_facet(cutoffs=(10,70))

# %%
arena.run_pairwise_comparisons_facet(metric="FinalPercentage",cutoffs=(10,70))

# %%
arena.plot_totaldistance_facet(cutoffs=(10,70))

# %%
arena.run_pairwise_comparisons_facet(metric="TotalDistance",cutoffs=(10,70))

# %%
arena.plot_transitions_facet(cutoffs=(10,70))

# %%
arena.run_pairwise_comparisons_facet(metric="Transitions",cutoffs=(10,70))

# %% [markdown]
# **Tracker plots:** These show, for each tracker individually, the progression of PI and Percentage showing cumulative values and time-dependent values

# %%
arena.plot_trackers_pis()

# %% [markdown]
# **Positional Plots:** Show the Y positions of each tracker as a function of time.

# %%
arena.plot_trackers_y(one_plot=True)

# %%
arena.plot_trackers_y()
