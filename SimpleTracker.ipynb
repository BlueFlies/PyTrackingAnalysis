# %% [markdown]
# # Simple Tracking Experiment

# %% [markdown]
# ## Notes
# **Overview:**
# **Rationale:**
# **Date of Experiment:**
# **Genotypes:**
# **Sex:**
# **Light Paradigm:**
# **Design:**
# **Misc:**

# %% [markdown]
# ## Configuration
# Configuration was standard. No new or untested code.

# %%
#%autoreload 1
import warnings
from Experiment import Experiment

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Setup
#
# Point `Experiment` at your project directory — the folder that contains `tracking_config.yaml`
# and a `data/` subfolder with the DTrack `.xlsx` and `.csv` files.
# Parameters are read automatically from the YAML; no manual `Parameters` object is needed.
#
# Expected layout:
# ```
# project_directory/
#     tracking_config.yaml
#     data/
#         ExperimentName.xlsx
#         ExperimentName_Data_1.csv  ...
#     analysis/   ← created automatically
#     qc/         ← created automatically
# ```

# %%
exp = Experiment('./TestingData/Prom2_Second')
#exp.experiment_summary();

# %% [markdown]
# ## Full Pipeline (one call)
#
# `run_analysis()` runs QC → summaries → plots → statistics in sequence and saves everything
# to `analysis/` and `qc/`.

# %%
exp.run_analysis();
# Out:
# === Running analysis for: ColosseumTemplate ===
#
# --- Quality Control ---
# === Data Quality: ColosseumTemplate ===
#
# Trackers passing ≥90% high-quality threshold: 22/24
#
# Tracker HighQuality NotFound Indiscernible StartMinutes EndMinutes
#   T_0_0       99.0%     1.0%          0.0%          0.0      768.5
#   T_1_0       99.5%     0.5%          0.0%          0.0      768.5
#   T_2_0       99.5%     0.5%          0.0%          0.0      768.5
#   T_3_0       99.5%     0.5%          0.0%          0.0      768.5
#   T_4_0       99.5%     0.5%          0.0%          0.0      768.5
#   T_5_0       99.5%     0.5%          0.0%          0.0      768.5
#   T_6_0       99.5%     0.5%          0.0%          0.0      768.5
#   T_7_0       99.5%     0.5%          0.0%          0.0      768.5
#   T_8_0       99.5%     0.5%          0.0%          0.0      768.5
#   T_9_0       99.5%     0.5%          0.0%          0.0      768.5
# ...

# %%
exp.plot_totaldistance_facet()
# Out:
# Saved: /home/scott/GithubLocal/PyTrackingAnalysis/TestingData/Prom2_Second/analysis/ColosseumTemplate_plot_totaldistance_facet.png

# %%
exp.experiment_summary()
# Out:
# === Experiment: ColosseumTemplate ===
#
# ── Paths ──────────────────────────────────────────────
#   Project   : /home/scott/GithubLocal/PyTrackingAnalysis/TestingData/Prom2_Second
#   Data      : /home/scott/GithubLocal/PyTrackingAnalysis/TestingData/Prom2_Second/Data/
#   Analysis  : /home/scott/GithubLocal/PyTrackingAnalysis/TestingData/Prom2_Second/analysis/
#   QC        : /home/scott/GithubLocal/PyTrackingAnalysis/TestingData/Prom2_Second/qc/
#
# ── Configuration ─────────────────────────────────────
#   Tracking type  : TRACKER
#   Tracking rig   : Colosseum
#   Facet cutoffs  : (30, 60, 90, 120, 150)
#   Design loaded  : Yes
#
# ── Parameters ────────────────────────────────────────
#   FPS                   : 0
#   mm / pixel            : 0.108
#   Speed window          : 1 s
#   Micro-move speed      : 0.2 – 2 mm/s
#   Walking speed         : ≥ 2 mm/s
#   Sleep threshold       : 5 min
#   Interaction distances : [8] mm
#
# ...
