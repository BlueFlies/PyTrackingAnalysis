# %%
#%autoreload 1

import importlib
import numpy
import pandas as pd
import os
import pickleshare
import Arena
import Tracker
import TwoChoiceTracker
import Parameters
import enum
import glob
from natsort import natsorted

#%aimport Tracker, Arena, Parameters, TwoChoiceTracker

importlib.reload(Arena)
importlib.reload(Tracker)
importlib.reload(TwoChoiceTracker)
importlib.reload(Parameters)

p = Parameters.Parameters()
#p.set_small_arena_values(Parameters.TrackingType.TWOCHOICETRACKER)
p.set_movie_values(Parameters.TrackingType.TWOCHOICETRACKER,8,0.056)
a = Arena.Arena('MaxIRSetup',p)
#a.first_tracker().plot_pis()
#print(a.first_tracker().rle())
#a.summarize()
#print(a.get_tracker("T_4_0"))
# Out:
#       Name TrackingRegion  ObjectID  ObsMinutes  TotalDistance  \
# 0    T_0_0            T_0         0   81.022917    3491.524011
# 1    T_1_0            T_1         0   81.022917    1550.389978
# 2   T_10_0           T_10         0   81.022917    3705.385086
# 3   T_11_0           T_11         0   81.022917    6406.655394
# 4   T_12_0           T_12         0   81.022917    9287.298806
# 5   T_13_0           T_13         0   81.022917    1645.341551
# 6   T_14_0           T_14         0   81.022917    9122.405843
# 7   T_15_0           T_15         0   81.022917    4414.947585
# 8   T_16_0           T_16         0   81.022917    6604.782544
# 9   T_17_0           T_17         0   81.022917    2532.243235
# 10  T_18_0           T_18         0   81.022917    3362.823017
# 11  T_19_0           T_19         0   81.022917    1801.566128
# 12   T_2_0            T_2         0   81.022917     837.895404
# 13  T_20_0           T_20         0   81.022917    5687.949891
# 14  T_21_0           T_21         0   81.022917    4225.767168
# 15  T_22_0           T_22         0   81.022917    2355.493761
# 16  T_23_0           T_23         0   81.022917    4015.681745
# 17  T_24_0           T_24         0   81.022917    6378.559034
# 18  T_25_0           T_25         0   81.022917    1790.334339
# 19  T_26_0           T_26         0   81.022917    1267.970190
# 20  T_27_0           T_27         0   81.022917    1736.409458
# 21  T_28_0           T_28         0   81.022917    2295.865134
# 22  T_29_0           T_29         0   81.022917    2455.786041
# 23   T_3_0            T_3         0   81.022917    1414.584619
# 24  T_30_0           T_30         0   81.022917    7950.448193
# 25  T_31_0           T_31         0   81.022917    3950.026980
# 26  T_32_0           T_32         0   81.022917    9424.360753
# 27  T_33_0           T_33         0   81.022917    4767.663540
# 28  T_34_0           T_34         0   81.022917    2104.762861
# 29  T_35_0           T_35         0   81.022917    2059.176024
# 30   T_4_0            T_4         0   81.022917     969.296874
# 31   T_5_0            T_5         0   81.022917    2365.849134
# 32   T_6_0            T_6         0   81.022917    7311.315941
# 33   T_7_0            T_7         0   81.022917    6386.860299
# 34   T_8_0            T_8         0   81.022917    2727.907189
# 35   T_9_0            T_9         0   81.022917    4976.219713
#
#     TotalDistanceDTrack  PercSleeping  PercWalking  PercMicro  PercResting  \
# 9   0.520359      0.002083      81.025 -0.561006   8502  30232           56
# 10  0.691832      0.002083      81.025  0.336749  12817  25832           70
# 11  0.370546      0.002083      81.025  0.679061   6223  32557           28
# 12  0.170542      0.002083      81.025 -0.936676   1230  37618           16
# 13  1.169024      0.002083      81.025  0.472150  10050  28029          133
# 14  0.865716      0.002083      81.025 -0.325660  25627  13036          106
# 15  0.484409      0.002083      81.025 -0.225333  23130  14623           56
# 16  0.822641      0.002083      81.025  0.561192   8399  29882           99
# 17  1.309439      0.002083      81.025 -0.150901  21973  16211          150
# 18  0.367703      0.002083      81.025  0.616493   7413  31246           39
# 19  0.260849      0.002083      81.025 -0.077936  20719  17723           21
# 20  0.356248      0.002083      81.025 -0.886680  36578   2197           30
# 21  0.470463      0.002083      81.025 -0.532038  29684   9067           56
# 22  0.504983      0.002083      81.025  0.745433   4759  32630           57
# 23  0.287342      0.002083      81.025  0.858104  26242   2004           14
# 24  1.633218      0.002083      81.025  0.187908  15608  22831          184
# 25  0.810832      0.002083      81.025  0.648264   6801  31870          105
# 26  1.938185      0.002083      81.025 -0.050660  20086  18149          221
# 27  0.978489      0.002083      81.025  0.384390  11760  26446          116
# 28  0.432861      0.002083      81.025 -0.616449  31073   7373           44
# 29  0.421491      0.002083      81.025  0.702850   5765  33037           44
# 30  0.196496      0.002083      81.025 -0.923699   1449  36532           20
# 31  0.484570      0.002083      81.025 -0.617950   7360  31169           51
# 32  1.503595      0.002083      81.025  0.012371  19559  19081          183
# 33  1.313433      0.002083      81.025 -0.228219  14900  23712          143
# 34  0.560944      0.002083      81.025  0.612109  30913   7438           52
# 35  1.021491      0.002083      81.025  0.096361  20804  17147          123

# %%
import importlib
import ExperimentalDesign
import Parameters 

importlib.reload(Parameters)
importlib.reload(ExperimentalDesign)
p=Parameters.Parameters()
e = ExperimentalDesign.ExperimentalDesign("MaxIRSetup",p)
# Out:
# Experimental Design for MaxIRSetup:
# Tracking Regions:
# None
# Counting Regions:
# None

# %%
a=glob.glob("*_Data_*.csv")
natsorted(a)
# Out:
# ['MaxIRSetup_Data_1.csv',
#  'MaxIRSetup_Data_2.csv',
#  'MaxIRSetup_Data_3.csv',
#  'MaxIRSetup_Data_4.csv',
#  'MaxIRSetup_Data_5.csv',
#  'MaxIRSetup_Data_6.csv',
#  'MaxIRSetup_Data_7.csv',
#  'MaxIRSetup_Data_8.csv',
#  'MaxIRSetup_Data_9.csv',
#  'MaxIRSetup_Data_10.csv',
#  'MaxIRSetup_Data_11.csv',
#  'MaxIRSetup_Data_12.csv',
#  'MaxIRSetup_Data_13.csv',
#  'MaxIRSetup_Data_14.csv']

# %%
1:3
# Out:
#   Cell In[97], line 1
#     1:3
#     ^
# SyntaxError: illegal target for annotation

# %%
a=[1,2]

# %%
len(a)
# Out:
# 2
