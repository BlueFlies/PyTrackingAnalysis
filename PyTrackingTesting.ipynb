# %%
# %autoreload 1

import importlib
import numpy
import pandas as pd
import os
import pickleshare
import Arena
import Tracker
import Parameters

# %aimport Tracker, Arena, Parameters

importlib.reload(Arena)
importlib.reload(Tracker)
importlib.reload(Parameters)

csv_file='Test.csv'
p = Parameters.Parameters()
p.set_small_arena_values()
a = Arena.Arena(csv_file,p)
print(a.firstTracker())
# Out:
# Tracker(name=T1_0, fps=0, head=
#    ObjectID TrackingRegion   X   Y  RelX  RelY  Frame  MSec CountingRegion  \
# 0         0             T1  34  92   -58     5      2   500           None
# 1         0             T1  32  79   -60    -8      3  1000           None
# 2         0             T1  37  67   -55   -20      4  1500           None
# 3         0             T1  37  66   -55   -21      5  2000           None
# 4         0             T1  34  72   -58   -15      6  2500           None
#
#    Direction  ...  Ypos_mm   Dist_mm  DeltaSec  DistWindow_mm DeltaSecWindow  \
# 0  -1.000000  ...    0.280  0.000000       0.0       0.000000            0.0
# 1  99.462322  ...   -0.448  0.736565       0.5       0.736565            0.5
# 2  -1.000000  ...   -1.120  0.728000       0.5       1.464565            1.0
# 3  90.000000  ...   -1.176  0.056000       0.5       0.784000            1.0
# 4  -1.000000  ...   -0.840  0.375659       0.5       0.431659            1.0
#
#   Speed_mm_sec  IsWalking  IsMicroMove  IsResting IsSleeping
# 0     0.000000      False        False       True       None
# 1     1.473130      False         True      False       None
# 2     1.464565      False         True      False       None
# 3     0.784000      False         True      False       None
# 4     0.431659      False         True      False       None
#
# [5 rows x 32 columns],tail=
#       ObjectID TrackingRegion    X   Y  RelX  RelY  Frame     MSec  \
# 7252         0             T1  125  81    33    -6   7254  3626500
# 7253         0             T1  125  81    33    -6   7255  3627000
# 7254         0             T1  125  81    33    -6   7256  3627500
# 7255         0             T1  125  78    33    -9   7257  3628000
# 7256         0             T1  116  80    24    -7   7258  3628500
#
#      CountingRegion  Direction  ...  Ypos_mm   Dist_mm  DeltaSec  \
# 7252              R      315.0  ...   -0.336  0.079196       0.5
# 7253              R       -1.0  ...   -0.336  0.000000       0.5
# 7254              R        0.0  ...   -0.336  0.000000       0.5
# 7255              R       -1.0  ...   -0.504  0.168000       0.5
# 7256              R      180.0  ...   -0.392  0.516294       0.5
#
#       DistWindow_mm DeltaSecWindow Speed_mm_sec  IsWalking  IsMicroMove  \
# 7252       0.583196            1.0     0.583196      False         True
# 7253       0.079196            1.0     0.079196      False        False
# 7254       0.000000            1.0     0.000000      False        False
# 7255       0.168000            1.0     0.168000      False        False
# 7256       0.684294            1.0     0.684294      False         True
#
#       IsResting IsSleeping
# 7252      False       None
# 7253       True       None
# 7254       True       None
# 7255       True       None
# 7256      False       None
#
# [5 rows x 32 columns])

# %%
a= pd.Series([1,2,3,4,5])

# %%
a.index=['a','b','c','d','e']

# %%
a['a']
# Out:
# 1
