# %% [markdown]
# ## Configuration
# The following cell is required to load the appropriate modules and ensure they are updated if there are live changes to the code files.

# %%
#%autoreload 1
import warnings
from Arena import *
import Tracker
import TwoChoiceTracker
from ExperimentalDesign import *
from Parameters import *

# Suppress all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Define the Parameters
# Next, create a parameters object that will hold information about the physical arena, camera settings, etc.
#
# The constructor just takes the type of tracker.  For now, we just have a two choice tracker implemented.
#
# This object has several member functions that allow you to automatically set several parameters based on common setups in the lab.

# %%
p=Parameters()
p.set_arena_max_values(TrackingType.TWOCHOICETRACKER)

# %% [markdown]
# ## Read in the data
#
# Next we will read in the data to an Arena object. The format is _Arena(ExperimentName, parameters, data_path="./")_. This will automatically calculate all relevant metrics for the tracking type in question.
#
# The name of the experiment and predefined parameters object are required.  data_path is optional (if no data directory is specified, it defaults to the current working directory).
#
# The following files must be present in the defined data directory :
# * The DTrack experiment file, which is an excel sheet with the name '_ExperimentName.xlsx_'.
# * The DTrack data files themselves, which are named '_ExperimentName_Data_1.csv_', '_ExperimentName_Data_2.csv_', etc.
# * An experiment file (most of the time, definitely for a TwoChoiceTracker), which is named '_ExperimentName_Design.txt_'.

# %%
arena = Arena.Arena('MaxIRSetup',p,data_path='./Data/')

# %% [markdown]
# ## View Results
# There are lots of ways to view the results.  You can get the summary results for all trackers, including treatments, etc.

# %%
arena.summarize()
# Like many functions, you can supply a range of minutes to confine the analysis.
arena.summarize(range_minutes=(20,30))
# You can also write the results to the clipboard to paste in excel and/or output to a csv file in the data directory
arena.summarize(write_to_csvfile=True)
# Out:
#    Treatment    Name TrackingRegion  ObjectID  ObsMinutes  TotalDistance  \
# 0    Control   T_0_0            T_0         0   80.024963   14390.052218
# 1       R2R4   T_1_0            T_1         0   80.024963    8958.863307
# 2   Control4  T_10_0           T_10         0   80.024963   10190.696114
# 3       R2R4  T_11_0           T_11         0   80.024963   15468.680901
# 4   Control4  T_12_0           T_12         0   80.024963   18296.753213
# 5       R2R4  T_13_0           T_13         0   80.024963   28460.408444
# 6    Control  T_14_0           T_14         0   80.024963   20329.615151
# 7       R2R4  T_15_0           T_15         0   80.024963   22371.869513
# 8   Control4  T_16_0           T_16         0   80.024963   10762.418231
# 9       R2R4  T_17_0           T_17         0   80.024963   17616.496150
# 10   Control  T_18_0           T_18         0   80.024963   17146.811300
# 11      R2R4  T_19_0           T_19         0   80.024963   12378.916210
# ...

# %% [markdown]
# ## Plotting
# There are lots of cool plotting funtions.  Some are shown below.

# %%
arena.summarize(write_to_csvfile=True)
# Out:
# WTF
# hi
#    Treatment    Name TrackingRegion  ObjectID  ObsMinutes  TotalDistance  \
# 0    Control   T_0_0            T_0         0   80.024963   14390.052218
# 1       R2R4   T_1_0            T_1         0   80.024963    8958.863307
# 2   Control4  T_10_0           T_10         0   80.024963   10190.696114
# 3       R2R4  T_11_0           T_11         0   80.024963   15468.680901
# 4   Control4  T_12_0           T_12         0   80.024963   18296.753213
# 5       R2R4  T_13_0           T_13         0   80.024963   28460.408444
# 6    Control  T_14_0           T_14         0   80.024963   20329.615151
# 7       R2R4  T_15_0           T_15         0   80.024963   22371.869513
# 8   Control4  T_16_0           T_16         0   80.024963   10762.418231
# 9       R2R4  T_17_0           T_17         0   80.024963   17616.496150
# 10   Control  T_18_0           T_18         0   80.024963   17146.811300
# 11      R2R4  T_19_0           T_19         0   80.024963   12378.916210
# ...
