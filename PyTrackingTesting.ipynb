# %%
#%autoreload 1

import importlib
import numpy
import pandas as pd
import os
import pickleshare
import Arena
import Tracker
import TwoChoiceTracker
import Parameters
import enum
import glob
from natsort import natsorted

#%aimport Tracker, Arena, Parameters, TwoChoiceTracker

importlib.reload(Arena)
importlib.reload(Tracker)
importlib.reload(TwoChoiceTracker)
importlib.reload(Parameters)

p = Parameters.Parameters()
#p.set_small_arena_values(Parameters.TrackingType.TWOCHOICETRACKER)
p.set_movie_values(Parameters.TrackingType.TWOCHOICETRACKER,8,0.056)
a = Arena.Arena('MaxIRSetup',p)
print("hi")
#a.plot_treatments()
#a.first_tracker().plot_pis()
#print(a.first_tracker().rle())
#a.summarize()
#print(a.get_tracker("T_4_0"))
# Out:
# hi

# %%
a.first_tracker().get_pi_subset([10,10.5])
a.first_tracker().get_cumulative_percentage([10,10.5])
# Out:
#        Minutes  CumulativePercentage  PI  Percentage    Off     On  Indicator
# 0    10.000000              1.000000   1           1   True  False          2
# 1    10.002083              1.000000   1           1   True  False          0
# 2    10.004167              1.000000   1           1   True  False          0
# 3    10.006250              1.000000   1           1   True  False          0
# 4    10.008333              1.000000   1           1   True  False          0
# ..         ...                   ...  ..         ...    ...    ...        ...
# 236  10.491667              0.139241  -1           0  False   True          0
# 237  10.493750              0.138655  -1           0  False   True          0
# 238  10.495833              0.138075  -1           0  False   True          0
# 239  10.497917              0.137500  -1           0  False   True          0
# 240  10.500000              0.136929  -1           0  False   True          0
#
# [241 rows x 7 columns]

# %%
1:10
# Out:
#   Cell In[11], line 1
#     1:10
#     ^
# SyntaxError: illegal target for annotation

# %%
a=glob.glob("*_Data_*.csv")
natsorted(a)
# Out:
# ['MaxIRSetup_Data_1.csv',
#  'MaxIRSetup_Data_2.csv',
#  'MaxIRSetup_Data_3.csv',
#  'MaxIRSetup_Data_4.csv',
#  'MaxIRSetup_Data_5.csv',
#  'MaxIRSetup_Data_6.csv',
#  'MaxIRSetup_Data_7.csv',
#  'MaxIRSetup_Data_8.csv',
#  'MaxIRSetup_Data_9.csv',
#  'MaxIRSetup_Data_10.csv',
#  'MaxIRSetup_Data_11.csv',
#  'MaxIRSetup_Data_12.csv',
#  'MaxIRSetup_Data_13.csv',
#  'MaxIRSetup_Data_14.csv']

# %%
1:3
# Out:
#   Cell In[97], line 1
#     1:3
#     ^
# SyntaxError: illegal target for annotation

# %%
a=[1,2]

# %%
len(a)
# Out:
# 2
